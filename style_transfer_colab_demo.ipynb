# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamswarnkar/Style-Transfer/blob/master/style_transfer_colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Style Transfer Demo
# Use GPU for faster training.
# Activate GPU through Edit Menu --> Notebook Settings --> Hardware Acc --> GPU

# %%
# !git clone https://github.com/shivamswarnkar/Style-Transfer.git style-transfer
# %cd style-transfer
# !ls
# Out:
# Cloning into 'style-transfer'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 65 (delta 7), reused 52 (delta 3), pack-reused 0
# Unpacking objects: 100% (65/65), done.
# /content/style-transfer
# demo  LICENSE  README.md       style_transfer_colab_demo.ipynb	utils
# imgs  output   style_transfer  transfer.py

# %%
# !python transfer.py --steps 2
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:07<00:00, 81.6MB/s]
# starting style transfer of imgs/style5.jpg into imgs/content3.jpg
# <Figure size 640x480 with 1 Axes>

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = Image.open('imgs/style4.jpg')
plt.axis("off")
plt.imshow(img)

# %%
img = Image.open('imgs/content3.jpg')
plt.axis("off")
plt.imshow(img)

# %% [markdown]
# # Style Transfer Examples

# %%
from style_transfer import style_transfer

# %%
style_transfer('imgs/content3.jpg', 'imgs/style4.jpg', steps=4000)
# Out:
# starting style transfer of imgs/style4.jpg into imgs/content3.jpg
# Total loss:34.6991	Saved as output/output.jpg
# Total loss:11.1543	Saved as output/output.jpg
# Total loss:6.3524	Saved as output/output.jpg
# Total loss:4.3638	Saved as output/output.jpg
# Total loss:3.1907	Saved as output/output.jpg
# Total loss:2.3961	Saved as output/output.jpg
# Total loss:1.8311	Saved as output/output.jpg
# Total loss:1.4223	Saved as output/output.jpg
# Total loss:1.1258	Saved as output/output.jpg
# Total loss:0.9097	Saved as output/output.jpg

# %%
style_transfer('imgs/content1.jpg', 'imgs/style1.jpg', steps=4000)
# Out:
# starting style transfer of imgs/style1.jpg into imgs/content1.jpg
# Total loss:35.6993	Saved as output/output.jpg
# Total loss:14.0040	Saved as output/output.jpg
# Total loss:8.2036	Saved as output/output.jpg
# Total loss:5.8110	Saved as output/output.jpg
# Total loss:4.4806	Saved as output/output.jpg
# Total loss:3.5806	Saved as output/output.jpg
# Total loss:2.9082	Saved as output/output.jpg
# Total loss:2.3860	Saved as output/output.jpg
# Total loss:1.9681	Saved as output/output.jpg
# Total loss:1.6268	Saved as output/output.jpg

# %%
style_transfer('imgs/content2.jpg', 'imgs/style2.jpg', steps=4000)
# Out:
# starting style transfer of imgs/style2.jpg into imgs/content2.jpg
# Total loss:43.3982	Saved as output/output.jpg
# Total loss:12.1988	Saved as output/output.jpg
# Total loss:5.3856	Saved as output/output.jpg
# Total loss:2.2227	Saved as output/output.jpg
# Total loss:1.6436	Saved as output/output.jpg
# Total loss:1.2663	Saved as output/output.jpg
# Total loss:0.9999	Saved as output/output.jpg
# Total loss:0.8023	Saved as output/output.jpg
# Total loss:0.6520	Saved as output/output.jpg

# %% [markdown]
# # Transfer Style using URL of images

# %%
# This is the content image we'll use for demo
content = 'imgs/content4.jpg'

# %%
# show image
img = Image.open(content)
plt.axis("off")
plt.imshow(img)

# %%
# Style image from web
style = 'https://previews.123rf.com/images/ievgeniiaz/ievgeniiaz1303/ievgeniiaz130300013/18391517-seamless-decorative-mozaic-pattern.jpg'

# %%
# View Image from URL
from utils.img_utils import load_image, im_convert
img = load_image(style)
plt.imshow(im_convert(img))
plt.axis('off')
plt.show()

# %%
style_transfer(content, style, steps=4000)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:08<00:00, 64.0MB/s]
# starting style transfer of https://previews.123rf.com/images/ievgeniiaz/ievgeniiaz1303/ievgeniiaz130300013/18391517-seamless-decorative-mozaic-pattern.jpg into imgs/content4.jpg
# Total loss:306.8642	Saved as output/output.jpg
# Total loss:126.6906	Saved as output/output.jpg
# Total loss:67.1723	Saved as output/output.jpg
# Total loss:41.8528	Saved as output/output.jpg
# Total loss:28.9676	Saved as output/output.jpg
# Total loss:21.3136	Saved as output/output.jpg
# Total loss:16.3023	Saved as output/output.jpg
# Total loss:12.8365	Saved as output/output.jpg
# Total loss:10.3269	Saved as output/output.jpg
# Total loss:8.4477	Saved as output/output.jpg

# %%
style = 'http://derecjones.com/wp-content/uploads/2019/01/Mozaic-A.jpg'

# %%
img = load_image(style)
plt.imshow(im_convert(img))
plt.axis('off')
plt.show()

# %%
style_transfer(content, style, steps=4000)
# Out:
# starting style transfer of http://derecjones.com/wp-content/uploads/2019/01/Mozaic-A.jpg into imgs/content4.jpg
# Total loss:162.1079	Saved as output/output.jpg
# Total loss:93.7067	Saved as output/output.jpg
# Total loss:58.9000	Saved as output/output.jpg
# Total loss:37.2836	Saved as output/output.jpg
# Total loss:25.2202	Saved as output/output.jpg
# Total loss:17.9972	Saved as output/output.jpg
# Total loss:13.2814	Saved as output/output.jpg
# Total loss:10.0627	Saved as output/output.jpg
# Total loss:7.8001	Saved as output/output.jpg
# Total loss:6.1685	Saved as output/output.jpg
